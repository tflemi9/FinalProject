# %% [markdown]
# # Creating a simulation model to aid in managing habitats for a protected reserve.

# %%
#Import necessary modules
import random
from copy import copy
import matplotlib.pyplot as plt

# %%
#Define the individual class.

#not sure if the list of different phenotypes should be used for individual or population 
#project says each population should have inidividuals with same phenotype 
colors = ["red", "orange", "yellow", "green", "blue", "purple"]

class individual:
    # Add a docstring     
    def __init__(self,id ="0", x= "0",y= "0",colorNumber = 0): # Add default values and color phenotype.
        # Add a docstring
        self.x = x
        self.y = y
        self.colorNumber = colors[colorNumber]
    def move(self): # Add necessary arguments
        # Add a docstring

# %%
#Define the population class.

colors = ["red", "orange", "yellow", "green", "blue", "purple"]

class population:
  #add docstring
  def __init__(self,,popSize = 20 ,colorNumber = 0): # Add default values and starting population size.
        # Add a docstring
        self.popSize = popSize
        self.colorNumber = colors[colorNumber]
        self.list=[] #create list of individuals

    #def move(self): # Add necessary arguments
        # Add a docstring
        #for i in self.individ: #for loop to cause each individual to move
           # i.move() #.move() method
    #def listLocations(self): # Add necessary arguments
        # Add a docstring
        #for i in self.individ: #for loop to print description of locations
           # i.printLocation()  
    #def draw(self): # Add necessary arguments
        # Add a docstring
        #for i in self.individ: #for loop to plot location of individuals in population
            #plt.figure(x= i.x, y= i.y) --> From Assignment 12 and 11
        #plt.xlabel('') #creating x axis label
        #plt.ylabel(''.format(Input1,Input2)) #creating y axis label where it
        
        #code for multiple lines may go here??
        
        #plt.xticks(rotation=90) #rotate x axis labels by 90 degrees
        #plt.grid(True) #adding a grid
        #plt.plot(xaxis, yaxis)
        #plt.show()

#***Have methods to add and remove individuals on the list for the population

    def add(self):
        list.append(self)
    def remove(self):
        list.remove(self)
    
   
 
#calculate and print the frequency of phenotypes among individuals.

#just placing this here for now...Maybe a way to get frequency???
# Python program to count the frequency of  
# individuals in a list using a dictionary 
  
#def CountFrequency(my_list): 
  
    # Creating an empty dictionary  
    #freq = {} 
    #for item in my_list: 
        #if (item in freq): 
            #freq[item] += 1
        #else: 
            #freq[item] = 1
  
    #for key, value in freq.items(): 
        #print ("% d : % d"%(key, value)) 
  
#Driver function 
#if __name__ == "__main__":  
    #my_list =[] 
  
    #CountFrequency(my_list)

# %%
#Define the landscape class.
class landscape:
  #add dosctring
  def __init__(self,landscapeSize=3): #Add default values.
    # Add a docstring
    self.landscapeSize = landscapeSize
    self.list=[] #create list of populations


#a method that uses the probabilities in the dispersal
#matrix to determine if an individual moves or stays each time step. 
  #need to look at if the list of population sizes change 

#Create Dispersal Matrix.
#Use random.choices() method.
#If an individual moves from one population      
#to another, you should remove it from the list of individuals in the population where    
#it started, and add it to the list of individuals in the population where it went.

# %%
# need help with creating the objects and putting them in the list while not iterating thorugh for loop 
   # need help assigning different color phenotypes from colors list to each population of individuals   
    #create a landscape object for landscape class 
    newLandscape = landscape() #default values 

    #create populations based on landscape size 
    #add populations to landscape list 

    for i in range(landscapeSize): #for every population in the landscape
        newPop = population(colorNumber = i) #create an object for that population

        for j in newLandscape.list:
            newLandscape.list[j] = newPop  #add the population into the landscape list with the populations
        #add(newPop.individ, self.pop) 
        #do you add list or obj?


    newLandscape.list = [population(colorNumber = i) for i in range(landscapeSize)]
      for i in newLandscape.list:
          newLandscape.list.add(i)

        
        
    #have your populations
    #need to create individuals with those colors
    #for loop going through every population in the newLandscape.list  
        # condition statement where if population.colorNumber = individual.colorNumher 
            # put that individual in that popluation's list 
    
        self.individ = [individual() for i in range(popSize/landscapeSize)]
        for i in self.individ:
            self.colorNumber = color[i]
            self.individ.add(i)

        self.individ2 = [individual(color = "blue") for i in range(popSize/landscapeSize)]
        for i in self.individ2:
            self.individ2.add(i)
        

      self.pop = [population() for i in range(landscapeSize)]
      for i in in self.pop:
          self.pop.add(i)
      
      
      for i in range(popsize):
            #create an individual object based on how many inidivduals are in a population 
      
        for i in range(landscapeSize):
            #create a population 
                #creates a list for that population of individuals 
            add(population, self.pop) #add the populations 
                                      #into the landscape list of populations
    

        for i in range population list:
            for i in range population:
                self.ind.append(individual(id = i, color = "blue"))


        self.ind=[] #list of individuals in population
        for i in range(popSize):
            self.ind.append(individual(id = i, color = "blue"))

# %%
#Code to create plots of phenotype frequencies that shows three different lines
#for three different populations.

#not sure if code for multiple plots goes here or in a class???

# %%
#Code to create plots of population sizes that shows three different lines
#for three different populations.
